# %% [markdown]
# # Variables

# %%
# Declaring and Assigining Variables

age = 32
height = 6.1
name = "Ahmed"
is_student = True

## printing the variables

print("age:", age) 
print("Height:", height)
print("Name:", name)
# Out:
# age: 32
# Height 6.1
# Name: Ahmed

# %%
age = 32
height = 6.1
name = "Ahmed"
is_student = True

print(f"My name is {name}, I am {height}cm tall.\
     I am {age} years old")
# Out:
# My name is Ahmed, I am 6.1cm tall.     I am 32 years old

# %%
'''
Naming Converntions
1. variable names should be descriptive
2. They must start with a letter or an '_' and contains letter, numbers and underscores
3. Variables names case sensitive
'''

# Valid variable names

first_name="Krish"
last_name = "Naik"

# %%
#Ivalid Variable names

2age=30
first-name="Krish"
@name = "Kirsh"

# %%
## Understanding Variable types
## Python is dynamically typed, type of a variable is determined at runtime

age = int(input("Enter your age:",))
print(age, type(age))
# Out:
# 80 <class 'int'>

# %%
### Simple calculator

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
sum = num1 + num2
if num1>num2:
    difference = num1 - num2
else:
    difference = num2 - num1
product = num1 * num2
quotient = round(num1/num2,2)

print("Sum:", sum)
print("Difference:", difference)
print("Product:", product)
print("Quotient:", quotient)
# Out:
# Sum: 23.0
# Difference: 17.0
# Product: 60.0
# Quotient: 6.67

# %%
### Simple calculator
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

sum = num1 + num2
difference = abs(num1 - num2)
product = num1 * num2
quotient = num1/num2

print("Sum:", sum)
print("Difference:", difference)
print("Product:", product)
print("Quotient:", quotient)
# Out:
# Sum: 30.0
# Difference: 10.0
# Product: 200.0
# Quotient: 0.5
