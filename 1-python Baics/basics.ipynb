# %%
1+1
# Out:
# 2

# %%
print("Hello World")
# Out:
# Hello World

# %%
# This is a single line comment
'''
multiple line comments
'''
# use backlash to continue code on next line

total=1+2+3+4+\
    5

print(total)
# Out:
# 15

# %%
# Multiple Statements on a single line

x = 5; y=10; z=x+y
print(z)
# Out:
# 15

# %%
# write a code to add two numbers

print("THIS CODE PRINT TWO NUMBERS YOU INPUT AND RETURN RESULT")
x=input("Enter first number:")
y=input("Enter Second number:")
ix=int(x)
iy=int(y)
z=ix+iy
print(f"The sum of {x} and {y} is {z}")

# %%
type(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 type(name)
#
# NameError: name 'name' is not defined

# %%
### fish

# %% [markdown]
# ### fish

# %%
type(fish)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 type(fish)
#
# NameError: name 'fish' is not defined

# %%
type("fish")
# Out:
# str

# %%
type(0.1)
# Out:
# float

# %%
type(fish)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 type(fish)
#
# NameError: name 'fish' is not defined

# %%
age = 32
if age>30:
    print(age)
# Out:
# 32

# %%
age = 32
print(age+1)
# Out:
# 33

# %%
## Code examples of indentation
if True:
    print("Correct Indentation")
    if False:
        print("This not print")
    print("This will print")
print("Outside the if block")
