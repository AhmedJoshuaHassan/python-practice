# %% [markdown]
# # Data Types

# %%
## string datatype example
name="Krish"
print(name)
print(type(name))
# Out:
# Krish
# <class 'str'>

# %%
## boolean datatype
is_true = True
type(is_true)
# Out:
# bool

# %%
## common errors
# result = "Hello" + 5
result = "Hello" + str(5)

print(result)
# Out:
# Hello5

# %%
str = "Hello"
str.
